# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pylab import *
import multiprocessing
import seaborn as sns
import os
# %matplotlib inline

pd.options.display.float_format = '{:,.2f}'.format
colors = plt.rcParams['axes.color_cycle']

# %%
def convert_bool(col):
    if str(col).title().lower() ==  "si": #check for nan
        return True
    elif str(col).title().lower() == "no":
        return False
    else:
        return np.nan

# %%
#Load file
fileName = os.path.join('resources','base','results25112015_preparsed_xrp_short_without_contador_roto_2.csv')
data = pd.read_csv(fileName, sep=";",decimal='.', na_values='', 
        converters={
        "ACTIVO": lambda x:convert_bool(x),
        "NO ACTIVO": lambda x:convert_bool(x),
        "JUBILADO": lambda x:convert_bool(x),
        "FUMA": lambda x:convert_bool(x),
        "ALCOHOL": lambda x:convert_bool(x),
        "DEPRESIÓN": lambda x:convert_bool(x),
        "ANSIEDAD": lambda x:convert_bool(x),
        "HTA": lambda x:convert_bool(x),        
        "CARDIOPATÍA": lambda x:convert_bool(x),
        "ENFERMEDAD NEUROLÓGICA": lambda x:convert_bool(x),
        "ENFERMEDAD RESPIRATORIA": lambda x:convert_bool(x),        
        "DIABETES": lambda x:convert_bool(x),
        "OBESIDAD": lambda x:convert_bool(x),
        "DISLIPEMIA": lambda x:convert_bool(x),
        "NEOPLASIA": lambda x:convert_bool(x),
        "OBSTRUCCIÓN NASAL CRÓNICA": lambda x:convert_bool(x),        
        "CIRUGÍA ORL": lambda x:convert_bool(x),
        "INSOMNIO": lambda x:convert_bool(x),
        "ACTIVIDAD MOTRIZ NOCTURNA": lambda x:convert_bool(x),
        "DOLOR DE PIERNAS CON NECESIDAD DE MOVERLAS": lambda x:convert_bool(x),
        "MOVIMIENTOS BRUSCOS INVOLUNTARIOS MIENTRAS DUERME": lambda x:convert_bool(x),   
        "CATAPLEJÍA": lambda x:convert_bool(x),        
        "SENSACION DE TENER SUEÑOS REALES AL QUEDARSE DORMIDO": lambda x:convert_bool(x),
        "SUEÑO INTERRUMPIDO POR PIROSIS": lambda x:convert_bool(x),
        "FROTA (RECHINA) LOS DIENTES MIENTRAS DUERME": lambda x:convert_bool(x),
        "DISMINUCION DEL DESEO O POTENCIA SEXUAL": lambda x:convert_bool(x),
        "IECAS": lambda x:convert_bool(x),
        "BBLOQ": lambda x:convert_bool(x),
        "DIURETICOS": lambda x:convert_bool(x),
        "CA-ANTAG": lambda x:convert_bool(x),
        "ARA-II": lambda x:convert_bool(x),
        "ANTIAGREG": lambda x:convert_bool(x),        
        "ANTICOAG": lambda x:convert_bool(x),        
        "ANTIACID": lambda x:convert_bool(x),        
        "BRONCODIL": lambda x:convert_bool(x),        
        "ADO": lambda x:convert_bool(x),        
        "INSULINA": lambda x:convert_bool(x),        
        "HIPOLIPEM": lambda x:convert_bool(x),        
        "BDZ": lambda x:convert_bool(x),        
        "ANTIDEPRE": lambda x:convert_bool(x),
        "OTROS PSICO": lambda x:convert_bool(x),
        "OTROS HIPOT": lambda x:convert_bool(x),
        "ABANDONO_1": lambda x:convert_bool(x),
        "ALERGIA/IRRITACIONES CUTAANEAS POR MASCARILLA_1": lambda x:convert_bool(x),
        "BOCA SECA_1": lambda x:convert_bool(x),
        "CONGESTION NASAL_1": lambda x:convert_bool(x),
        "SECRECCION NASAL_1": lambda x:convert_bool(x),
        "ESTORNUDOS_1": lambda x:convert_bool(x),
        "SINUSITIS_1": lambda x:convert_bool(x),
        "HEMORRAGIA NASAL_1": lambda x:convert_bool(x),
        "MALESTAR_1": lambda x:convert_bool(x),
        "OTROS_1": lambda x:convert_bool(x),
        "ABANDONO_3": lambda x:convert_bool(x),
        "ALERGIA/IRRITACIONES CUTAANEAS POR MASCARILLA_3": lambda x:convert_bool(x),
        "BOCA SECA_3": lambda x:convert_bool(x),
        "CONGESTION NASAL_3": lambda x:convert_bool(x),
        "SECRECCION NASAL_3": lambda x:convert_bool(x),
        "ESTORNUDOS_3": lambda x:convert_bool(x),
        "SINUSITIS_3": lambda x:convert_bool(x),
        "HEMORRAGIA NASAL_3": lambda x:convert_bool(x),
        "MALESTAR_3": lambda x:convert_bool(x),
        "FARMACOS QUITADOS_3": lambda x:convert_bool(x),
        "FARMACOS AÑADIDOS_3": lambda x:convert_bool(x),
        "OTROS_3": lambda x:convert_bool(x),
        "ABANDONO_6": lambda x:convert_bool(x),
        "ALERGIA/IRRITACIONES CUTAANEAS POR MASCARILLA_6": lambda x:convert_bool(x),
        "BOCA SECA_6": lambda x:convert_bool(x),
        "CONGESTION NASAL_6": lambda x:convert_bool(x),
        "SECRECCION NASAL_6": lambda x:convert_bool(x),
        "ESTORNUDOS_6": lambda x:convert_bool(x),
        "SINUSITIS_6": lambda x:convert_bool(x),
        "HEMORRAGIA NASAL_6": lambda x:convert_bool(x),
        "MALESTAR_6": lambda x:convert_bool(x),
        "OTROS_6": lambda x:convert_bool(x),
        "FARMACOS QUITADOS_6": lambda x:convert_bool(x),
        "FARMACOS AÑADIDOS_6": lambda x:convert_bool(x)
        })

print data.shape
print
print data.info()
print
print data.dtypes
# Out:
# (42, 135)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Columns: 135 entries, CODIGO to VISUAL EUROQOL_6
# dtypes: bool(33), float64(43), int64(7), object(52)
# memory usage: 34.9+ KB
# None
#
# CODIGO                                              object
# GENERO                                              object
# ACTIVO                                                bool
# NO ACTIVO                                             bool
# JUBILADO                                              bool
# EDAD                                                 int64
# FUMA                                                  bool
# DOSIS (PAQUETES /AÑO)                                int64
# AÑOS EXFUMADOR                                     float64
# ALCOHOL                                               bool
# DOSIS (GRAMOS/DÍA)                                 float64
# CAFÉS AL DÍA                                       float64
# ...

# %% [markdown]
# #### Convert column types

# %%
#Convert string to numeric values (no data is converted as Nan)
data['HORAS USO MEDIO NOCHE_1'] = pd.to_numeric(data['HORAS USO MEDIO NOCHE_1'],errors='coerce')
data['HORAS USO MEDIO NOCHE_3'] = pd.to_numeric(data['HORAS USO MEDIO NOCHE_3'],errors='coerce')
data['HORAS USO MEDIO NOCHE_6'] = pd.to_numeric(data['HORAS USO MEDIO NOCHE_6'],errors='coerce')

#data["ACTIVO"] = data["ACTIVO"].str.lower()
#data["NO ACTIVO"] = data["NO ACTIVO"].str.lower()
#data["OBESIDAD"] = data["OBESIDAD"].str.lower()

# %% [markdown]
# #### Evaluate column types

# %%
print data["GENERO"].unique(), pd.Series(data["GENERO"].unique()).equals(pd.Series(['M','H']))
print data["ACTIVO"].unique(), np.all(np.in1d(data["ACTIVO"].unique(),[True, False]))==True
print data["NO ACTIVO"].unique(), np.all(np.in1d(data["NO ACTIVO"].unique(),[True, False]))==True
print data["JUBILADO"].unique(), np.all(np.in1d(data["JUBILADO"].unique(),[True, False]))==True
print data["FUMA"].unique(), np.all(np.in1d(data["FUMA"].unique(),[True, False]))==True
print data["ALCOHOL"].unique(), np.all(np.in1d(data["ALCOHOL"].unique(),[True, False]))==True
print data["DEPRESIÓN"].unique(), np.all(np.in1d(data["DEPRESIÓN"].unique(),[True, False]))==True
print data["ANSIEDAD"].unique(), np.all(np.in1d(data["ANSIEDAD"].unique(),[True, False]))==True
print data["HTA"].unique(), np.all(np.in1d(data["HTA"].unique(),[True, False,np.nan]))==True
print data["CARDIOPATÍA"].unique(), np.all(np.in1d(data["CARDIOPATÍA"].unique(),[True, False]))==True
print data["ENFERMEDAD NEUROLÓGICA"].unique(), np.all(np.in1d(data["ENFERMEDAD NEUROLÓGICA"].unique(),[True, False]))==True
print data["ENFERMEDAD RESPIRATORIA"].unique(), np.all(np.in1d(data["ENFERMEDAD RESPIRATORIA"].unique(),[True, False]))==True
print data["DIABETES"].unique(), np.all(np.in1d(data["DIABETES"].unique(),[True, False]))==True
print data["OBESIDAD"].unique(), np.all(np.in1d(data["OBESIDAD"].unique(),[True, False]))==True
print data["DISLIPEMIA"].unique(), np.all(np.in1d(data["DISLIPEMIA"].unique(),[True, False]))==True
print data["NEOPLASIA"].unique(), np.all(np.in1d(data["NEOPLASIA"].unique(),[True, False]))==True
print data["OBSTRUCCIÓN NASAL CRÓNICA"].unique(), np.all(np.in1d(data["OBSTRUCCIÓN NASAL CRÓNICA"].unique(),[True, False]))==True
print data["CIRUGÍA ORL"].unique(), np.all(np.in1d(data["CIRUGÍA ORL"].unique(),[True, False]))==True
print "RONCA", data["RONCA"].unique(), np.all(np.in1d(data["RONCA"].unique(),['siempre', 'frecuentemente', 'a veces']))==True
print data["SUEÑO REPARADOR"].unique(), np.all(np.in1d(data["SUEÑO REPARADOR"].unique(),['siempre', 'frecuentemente', 'a veces','nunca']))==True
print data["CRISIS ASFICSICAS"].unique(), np.all(np.in1d(data["CRISIS ASFICSICAS"].unique(),['siempre','a veces','nunca']))==True
print data["NICTURIA"].unique(), np.all(np.in1d(data["NICTURIA"].unique(),['a veces', 'siempre', np.nan, 'frecuentemente', 'nunca']))==True
print data["APNEAS PRESENCIADAS"].unique(), np.all(np.in1d(data["APNEAS PRESENCIADAS"].unique(),['siempre', 'frecuentemente', 'a veces', 'nunca', np.nan]))==True
print data["CEFALEA"].unique(), np.all(np.in1d(data["CEFALEA"].unique(),['a veces', 'nunca', 'frecuentemente', 'siempre']))==True
print data["SOMNOLENCIA DIURNA"].unique(), np.all(np.in1d(data["SOMNOLENCIA DIURNA"].unique(),['frecuentemente', 'a veces','nunca', 'siempre']))==True
print data["DESPERTARES NOCTURNOS"].unique(), np.all(np.in1d(data["DESPERTARES NOCTURNOS"].unique(),['a veces', 'frecuentemente','nunca', 'siempre']))==True
print data["TRASTORNOS DE MEMORIA"].unique(), np.all(np.in1d(data["TRASTORNOS DE MEMORIA"].unique(),['frecuentemente','a veces',  'nunca']))==True
print data["TRASTORNOS DE CONCENTRACIÓN"].unique(), np.all(np.in1d(data["TRASTORNOS DE CONCENTRACIÓN"].unique(),['frecuentemente', 'a veces','nunca']))==True
print data["IRRITABILIDAD, APATÍA, DEPRESIÓN"].unique(), np.all(np.in1d(data["IRRITABILIDAD, APATÍA, DEPRESIÓN"].unique(),['a veces','frecuentemente','nunca']))==True
print data["INSOMNIO"].unique(), np.all(np.in1d(data["INSOMNIO"].unique(),[False,True]))==True
print data["ACTIVIDAD MOTRIZ NOCTURNA"].unique(), np.all(np.in1d(data["ACTIVIDAD MOTRIZ NOCTURNA"].unique(),[True,False]))==True
print data["DOLOR DE PIERNAS CON NECESIDAD DE MOVERLAS"].unique(), np.all(np.in1d(data["DOLOR DE PIERNAS CON NECESIDAD DE MOVERLAS"].unique(),[False,True]))==True
print data["MOVIMIENTOS BRUSCOS INVOLUNTARIOS MIENTRAS DUERME"].unique(), np.all(np.in1d(data["MOVIMIENTOS BRUSCOS INVOLUNTARIOS MIENTRAS DUERME"].unique(),[False, True, np.nan]))==True
print data["SUEÑO INTERRUMPIDO POR PIROSIS"].unique(), np.all(np.in1d(data["SUEÑO INTERRUMPIDO POR PIROSIS"].unique(),[False,True]))==True
print data["FROTA (RECHINA) LOS DIENTES MIENTRAS DUERME"].unique(), np.all(np.in1d(data["FROTA (RECHINA) LOS DIENTES MIENTRAS DUERME"].unique(),[False, True,np.nan]))==True
print data["DISMINUCION DEL DESEO O POTENCIA SEXUAL"].unique(), np.all(np.in1d(data["DISMINUCION DEL DESEO O POTENCIA SEXUAL"].unique(),[True, np.nan, False]))==True
print data["IECAS"].unique(), np.all(np.in1d(data["IECAS"].unique(),[False,True]))==True
print data["BBLOQ"].unique(), np.all(np.in1d(data["BBLOQ"].unique(),[False,True]))==True
print data["DIURETICOS"].unique(), np.all(np.in1d(data["DIURETICOS"].unique(),[False,True]))==True
print data["CA-ANTAG"].unique(), np.all(np.in1d(data["CA-ANTAG"].unique(),[False,True]))==True
print data["ARA-II"].unique(), np.all(np.in1d(data["ARA-II"].unique(),[False,True]))==True
print data["ANTIAGREG"].unique(), np.all(np.in1d(data["ANTIAGREG"].unique(),[False,True]))==True
print "ANTICOAG",data["ANTICOAG"].unique(), np.all(np.in1d(data["ANTICOAG"].unique(),[False,True]))==True
print data["ANTIACID"].unique(), np.all(np.in1d(data["ANTIACID"].unique(),[False,True]))==True
print data["BRONCODIL"].unique(), np.all(np.in1d(data["BRONCODIL"].unique(),[False,True]))==True
print data["ADO"].unique(), np.all(np.in1d(data["ADO"].unique(),[False,True]))==True
print data["INSULINA"].unique(), np.all(np.in1d(data["INSULINA"].unique(),[False,True]))==True
print data["HIPOLIPEM"].unique(), np.all(np.in1d(data["HIPOLIPEM"].unique(),[False,True]))==True
print data["BDZ"].unique(), np.all(np.in1d(data["BDZ"].unique(),[True,False]))==True
print data["ANTIDEPRE"].unique(), np.all(np.in1d(data["ANTIDEPRE"].unique(),[True,False]))==True
print data["OTROS PSICO"].unique(), np.all(np.in1d(data["OTROS PSICO"].unique(),[True,False,np.nan]))==True
print data["OTROS HIPOT"].unique(), np.all(np.in1d(data["OTROS HIPOT"].unique(),[False,np.nan,True]))==True

print data["ABANDONO_1"].unique(), np.all(np.in1d(data["ABANDONO_1"].unique(),[False,np.nan]))==True
print data["CONGESTION NASAL_1"].unique(), np.all(np.in1d(data["CONGESTION NASAL_1"].unique(),[False,True,np.nan]))==True
print data["SECRECCION NASAL_1"].unique(), np.all(np.in1d(data["SECRECCION NASAL_1"].unique(),[False,True,np.nan]))==True
print data["ESTORNUDOS_1"].unique(), np.all(np.in1d(data["ESTORNUDOS_1"].unique(),[False,True,np.nan]))==True
print data["SINUSITIS_1"].unique(), np.all(np.in1d(data["SINUSITIS_1"].unique(),[False,np.nan]))==True
print data["HEMORRAGIA NASAL_1"].unique(), np.all(np.in1d(data["HEMORRAGIA NASAL_1"].unique(),[False,np.nan]))==True
print data["MALESTAR_1"].unique(), np.all(np.in1d(data["MALESTAR_1"].unique(),[False,np.nan]))==True

print "ABANDONO_3",data["ABANDONO_3"].unique(), np.all(np.in1d(data["ABANDONO_3"].unique(),[False, np.nan, True]))==True
print data["ALERGIA/IRRITACIONES CUTAANEAS POR MASCARILLA_3"].unique(), np.all(np.in1d(data["ALERGIA/IRRITACIONES CUTAANEAS POR MASCARILLA_3"].unique(),[False, True, np.nan]))==True
print data["BOCA SECA_3"].unique(), np.all(np.in1d(data["BOCA SECA_3"].unique(),[True,False, np.nan]))==True
print data["CONGESTION NASAL_3"].unique(), np.all(np.in1d(data["CONGESTION NASAL_3"].unique(),[False, np.nan]))==True
print data["SECRECCION NASAL_3"].unique(), np.all(np.in1d(data["SECRECCION NASAL_3"].unique(),[False, np.nan]))==True
print data["ESTORNUDOS_3"].unique(), np.all(np.in1d(data["ESTORNUDOS_3"].unique(),[False, np.nan]))==True
print data["SINUSITIS_3"].unique(), np.all(np.in1d(data["SINUSITIS_3"].unique(),[False, np.nan]))==True
print data["HEMORRAGIA NASAL_3"].unique(), np.all(np.in1d(data["HEMORRAGIA NASAL_3"].unique(),[False, np.nan]))==True
print data["MALESTAR_3"].unique(), np.all(np.in1d(data["MALESTAR_3"].unique(),[False, np.nan,True]))==True
print data["FARMACOS AÑADIDOS_3"].unique(), np.all(np.in1d(data["FARMACOS AÑADIDOS_3"].unique(),[False, np.nan, True]))==True
print data["FARMACOS QUITADOS_3"].unique(), np.all(np.in1d(data["FARMACOS QUITADOS_3"].unique(),[False, True, np.nan]))==True

print data["ABANDONO_6"].unique(), np.all(np.in1d(data["ABANDONO_6"].unique(),[False, np.nan, True]))==True
print data["ALERGIA/IRRITACIONES CUTAANEAS POR MASCARILLA_6"].unique(), np.all(np.in1d(data["ALERGIA/IRRITACIONES CUTAANEAS POR MASCARILLA_6"].unique(),[ False,True,np.nan]))==True
print data["BOCA SECA_6"].unique(), np.all(np.in1d(data["BOCA SECA_6"].unique(),[False,True,np.nan]))==True
print data["CONGESTION NASAL_6"].unique(), np.all(np.in1d(data["CONGESTION NASAL_6"].unique(),[False,np.nan]))==True
print data["SECRECCION NASAL_6"].unique(), np.all(np.in1d(data["SECRECCION NASAL_6"].unique(),[False,np.nan,True]))==True
print data["ESTORNUDOS_6"].unique(), np.all(np.in1d(data["ESTORNUDOS_6"].unique(),[False,np.nan,True]))==True
print data["SINUSITIS_6"].unique(), np.all(np.in1d(data["SINUSITIS_6"].unique(),[False,np.nan]))==True
print data["HEMORRAGIA NASAL_6"].unique(), np.all(np.in1d(data["HEMORRAGIA NASAL_6"].unique(),[False,np.nan, True]))==True
print data["FARMACOS AÑADIDOS_6"].unique(), np.all(np.in1d(data["FARMACOS AÑADIDOS_6"].unique(),[False, True,np.nan]))==True
print data["FARMACOS QUITADOS_6"].unique(), np.all(np.in1d(data["FARMACOS QUITADOS_6"].unique(),[ False,True,np.nan]))==True
print data["MALESTAR_6"].unique().astype(float), np.all(np.in1d(data["MALESTAR_6"].unique().astype(float),np.array([False,float('nan'), True]).astype(float)))==True
# Out:
# ['H' 'M'] False
# [ True False] True
# [False  True] True
# [False  True] True
# [False  True] True
# [False  True] True
# [False  True] True
# [False  True] True
# [False  True] True
# [False  True] True
# [False True nan] False
# [ True False] True
# [False  True] True
# [False  True] True
# [False  True] True
# [False  True] True
# [True False nan] False
# [False True nan] False
# RONCA ['siempre' 'frecuentemente' 'a veces'] True
# ['a veces' 'frecuentemente' 'siempre' 'nunca'] True
# ['nunca' 'a veces' 'siempre'] True
# ['nunca' 'a veces' 'frecuentemente' 'siempre' nan] False
# ['frecuentemente' 'siempre' 'a veces' 'nunca' nan] False
# ['nunca' 'a veces' 'siempre' 'frecuentemente'] True
# ['siempre' 'nunca' 'a veces' 'frecuentemente'] True
# ['a veces' 'siempre' 'nunca' 'frecuentemente'] True
# ['nunca' 'frecuentemente' 'a veces'] True
# ['nunca' 'a veces' 'frecuentemente'] True
# ['a veces' 'nunca' 'frecuentemente'] True
# [False  True] True
# [False  True] True
# ...

# %% [markdown]
# #### Rename columns

# %%
print data.columns.tolist()
print len(data.columns)
data.columns = ["CODIGO","GENERO","ACTIVO","NO_ACTIVO","JUBILADO","EDAD","FUMA","FUMA_PAQ_ANY",
                "FUMA_EX_ANYS", "ALCOHOL", "ALCOHOL_GR_DIA", "CAFES_DIA", "DEPRESION","ANSIEDAD","HTA","CARDIOPATIA",
                "ENF_NEUR","ENF_RESP","DIABETES","OBESIDAD","DISLIPEMIA", 'NEOPLASIA',
                "OBSTR_NASAL_CRON","CIRUGIA_ORL","RONCA","SUE_REP","CRISIS_ASF","NICTURIA","APNEAS_PRES","CEFALEA",
                "SOMN_DIURN","DESPERTAR_NOCT","TRAST_MEM","TRAST_CONC","IRR_APAT_DEPR","INSOMNIO","ACT_MOTR_NOCT",
                "DOLOR_PIER_MOVER","MOV_BRUSC_INV_DUERME","SEN_SUE_REAL_DORM","SUE_INT_PIROSIS",
                "FROTA_DIENT_DUERM","DISM_DESEO_SEX","IECAS","BBLOQ","DIURETICOS","CA-ANTAG","ARA-II","ANTIAGREG",
                "ANTICOAG","ANTIACID","BRONCODIL","ADO","INSULINA","HIPOLIPEM","BDZ","ANTIDEPRE","OTROS_PSICO",
                "OTROS_HIPOT","TIEMP_SUENO","IAH",
                "TIEMPOSAT<90%","CT90%","IND_DESAT","PESO","TALLA","IMC","CIRC_CUELLO","CIRC_ABD","CIRC_CADERA"
                ,"MEDIA_TAS","MEDIA_TAD","Sat O2","PRESS_CPAP","EPWORTH","EUROQOL","VISUAL", 
                
                "HORAS_USO_TOT_1","HORAS_USO_MED_NOCHE_1","ABANDONO_1",
                "AL_IRR_CUT_MASC_1","BOCA_SECA_1","CONG_NASAL_1","SECR_NASAL_1","ESTORNUDOS_1","SINUSITIS_1",
                "HEMO_NASAL_1","MALESTAR_1","MEDIA_TAS_1",
                "MEDIA_TAD_1","EPWORTH_1","EUROQOL_1","VISUAL_EUROQOL_1",     
                
                "HORAS_USO_TOT_3","HORAS_USO_MED_NOCHE_3","ABANDONO_3",
                "AL_IRR_CUT_MAS_3","BOCA_SECA_3","CONG_NASAL_3","SECR_NASAL_3","ESTORNUDOS_3","SINUSITIS_3",
                "HEMO_NASAL_3","MALESTAR_3","MEDIA TAS_3",
                "MEDIA TAD_3","PESO_3","TALLA_3","IMC_3","FARMACOS ANADIDOS_3",
                "FARMACOS QUITADOS_3","EPWORTH_3","EUROQOL_3","VISUAL EUROQOL_3",
                
                "HORAS_USO_TOT_6","HORAS_USO_MED_NOCHE_6","ABANDONO_6",
                "AL_IRR_CUT_MAS_6","BOCA_SECA_6","CONG_NASAL_6","SECR_NASAL_6","ESTORNUDOS_6","SINUSITIS_6",
                "HEMO_NASAL_6","MALESTAR_6","MEDIA TAS_6",
                "MEDIA TAD_6","PESO_6","TALLA_6","IMC_6","FARMACOS ANADIDOS_6",
                "FARMACOS QUITADOS_6","EPWORTH_6","EUROQOL_6","VISUAL EUROQOL_6"
               ]
print len(data.columns)
# Out:
# ['CODIGO', 'GENERO', 'ACTIVO', 'NO ACTIVO', 'JUBILADO', 'EDAD', 'FUMA', 'DOSIS (PAQUETES /A\xc3\x91O)', 'A\xc3\x91OS EXFUMADOR', 'ALCOHOL', 'DOSIS (GRAMOS/D\xc3\x8dA)', 'CAF\xc3\x89S AL D\xc3\x8dA', 'DEPRESI\xc3\x93N', 'ANSIEDAD', 'HTA', 'CARDIOPAT\xc3\x8dA', 'ENFERMEDAD NEUROL\xc3\x93GICA', 'ENFERMEDAD RESPIRATORIA', 'DIABETES', 'OBESIDAD', 'DISLIPEMIA', 'NEOPLASIA', 'OBSTRUCCI\xc3\x93N NASAL CR\xc3\x93NICA', 'CIRUG\xc3\x8dA ORL', 'RONCA', 'SUE\xc3\x91O REPARADOR', 'CRISIS ASFICSICAS', 'NICTURIA', 'APNEAS PRESENCIADAS', 'CEFALEA', 'SOMNOLENCIA DIURNA', 'DESPERTARES NOCTURNOS', 'TRASTORNOS DE MEMORIA', 'TRASTORNOS DE CONCENTRACI\xc3\x93N', 'IRRITABILIDAD, APAT\xc3\x8dA, DEPRESI\xc3\x93N', 'INSOMNIO', 'ACTIVIDAD MOTRIZ NOCTURNA', 'DOLOR DE PIERNAS CON NECESIDAD DE MOVERLAS', 'MOVIMIENTOS BRUSCOS INVOLUNTARIOS MIENTRAS DUERME', 'SENSACION DE TENER SUE\xc3\x91OS REALES AL QUEDARSE DORMIDO', 'SUE\xc3\x91O INTERRUMPIDO POR PIROSIS', 'FROTA (RECHINA) LOS DIENTES MIENTRAS DUERME', 'DISMINUC
# ...

# %% [markdown]
# #### Mapping categorical values

# %%
#Nominal categories
mapping_1 = {'H': True, 'M': False}
data_mapped = data.replace({'GENERO': mapping_1})
print data_mapped.GENERO.head()

#Ordinal category
mapping_2 = {'nunca':0, 'a veces':1, 'frecuentemente':2, 'siempre':3}

data_mapped = data_mapped.replace({"RONCA":mapping_2})
data_mapped = data_mapped.replace({"NICTURIA":mapping_2})
data_mapped = data_mapped.replace({"APNEAS_PRES":mapping_2})
data_mapped = data_mapped.replace({"CEFALEA":mapping_2})
data_mapped = data_mapped.replace({"SOMN_DIURN":mapping_2})
data_mapped = data_mapped.replace({"DESPERTAR_NOCT":mapping_2})
data_mapped = data_mapped.replace({"TRAST_MEM":mapping_2})
data_mapped = data_mapped.replace({"TRAST_CONC":mapping_2})
data_mapped = data_mapped.replace({"IRR_APAT_DEPR":mapping_2})

print "CEFALEA:",data_mapped.CEFALEA.unique()
print "RONCA:",data_mapped.RONCA.unique()

mapping_3 = {'nunca':0, 'a veces':1, 'siempre':2}
data_mapped = data_mapped.replace({"CRISIS_ASF":mapping_3})
print "CRISIS_ASF:",data_mapped.CRISIS_ASF.unique()

mapping_4 = {'nunca':3, 'a veces':2, 'frecuentemente':1, 'siempre':0}
data_mapped = data_mapped.replace({"SUE_REP":mapping_4})

print "MAPPED MATRIX:",data_mapped.shape
data_mapped[["RONCA","SUE_REP","CRISIS_ASF","NICTURIA","APNEAS_PRES","CEFALEA",
                "SOMN_DIURN","DESPERTAR_NOCT","TRAST_MEM","TRAST_CONC","IRR_APAT_DEPR","INSOMNIO","ACT_MOTR_NOCT",
                "DOLOR_PIER_MOVER","MOV_BRUSC_INV_DUERME"]].head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: GENERO, dtype: bool
# CEFALEA: [0 1 3 2]
# RONCA: [3 2 1]
# CRISIS_ASF: [0 1 2]
# MAPPED MATRIX: (42, 135)
#    RONCA  SUE_REP  CRISIS_ASF  NICTURIA  APNEAS_PRES  CEFALEA  SOMN_DIURN  \
# 0      3        2           0      0.00         2.00        0           3
# 1      3        2           0      0.00         3.00        0           3
# 2      3        2           1      1.00         3.00        0           0
# 3      3        2           0      1.00         1.00        0           1
# 4      2        1           0      0.00         1.00        0           0
#
#    DESPERTAR_NOCT  TRAST_MEM  TRAST_CONC  IRR_APAT_DEPR  INSOMNIO  \
# 0               1          0           0              1     False
# 1               3          0           0              0     False
# 2               0          0           0              0     False
# 3               1          2           1              2     False
# ...

# %% [markdown]
# #### Save parsed data

# %%
fileName = os.path.join('resources','data_parsed_short_14012016.pkl')
data_mapped.to_pickle(fileName)
df = pd.read_pickle(fileName)
print df.shape
# Out:
# (42, 135)
